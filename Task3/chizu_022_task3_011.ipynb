# %% [markdown]
# <a href="https://colab.research.google.com/github/chizuchizu/IOAI/blob/main/Task3/chizu_022_task3_011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import importlib

if importlib.util.find_spec('datasets') is None:
    # !pip install -q torch==2.2.1 transformers==4.39.1 diffusers==0.27.2 torchvision==0.17.1 datasets==2.18.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 95.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 85.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 53.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 57.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 70.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 2.2.1 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.2.1 which is incompatible.

# %%
# ====================================================
# CFG
# ====================================================

class CFG:
    num_workers=4
    project = "IOAI_Task3"
    name = "chizu_022_011"
    base_model_name="lambdalabs/miniSD-diffusers"
    dataset_path = "/content/drive/MyDrive/dataset/COCO_10000_extracted"
    size=600
    scheduler='CosineAnnealingLR' # ['ReduceLROnPlateau', 'CosineAnnealingLR', 'CosineAnnealingWarmRestarts']

    learning_rate = 2e-05
    resolution = 256
    max_train_steps = 4000
    train_batch_size = 8

    eval_steps = 500

    #factor=0.2 # ReduceLROnPlateau
    #patience=4 # ReduceLROnPlateau
    #eps=1e-6 # ReduceLROnPlateau
    T_max=6 # CosineAnnealingLR
    #T_0=6 # CosineAnnealingWarmRestarts
    lr=1e-4
    min_lr=1e-6
    weight_decay=1e-6
    gradient_accumulation_steps=1
    max_grad_norm=1000
    seed=42
    train=True

    prompts = [
        "A curious zebra standing tall in a lush African savanna at sunrise, with acacia trees in the background.",
        "Next to a medieval castle, a regal zebra observes the knights and a drawbridge.",
        "Wearing a scarf, a fashionable giraffe strolls through a bustling city street with skyscrapers.",
        "Running along a sandy beach, a playful giraffe enjoys the palm trees, ocean waves, and a bright sunset.",
        "By a serene lakeside, a relaxed bear drinks water with mountains and a clear blue sky in the background.",
        "In a snowy forest, a cozy bear stands under snow-covered trees, enjoying the gentle snowfall.",
        "Partially hidden in a dense tropical rainforest, an adventurous sheep peeks through leafy plants.",
        "A sleek sheep with modern accessories navigates a futuristic city with flying cars and neon lights.",
    ]

# %%
# for wandb
cfg = dict(vars(CFG))
cfg = {k: v for k, v in cfg.items() if "__" not in k}

# %%
# load dataset
# !cp /content/drive/MyDrive/dataset/data_011.zip .
# !unzip data_011.zip
# Out:
# Archive:  data_011.zip
#    creating: data/
#   inflating: data/data.csv
#    creating: data/train/
#   inflating: data/train/186.png
#   inflating: data/train/37.png
#   inflating: data/train/343.png
#   inflating: data/train/1012.png
#   inflating: data/train/625.png
#   inflating: data/train/61.png
#   inflating: data/train/598.png
#   inflating: data/train/284.png
#   inflating: data/train/816.png
#   inflating: data/train/1080.png
#   inflating: data/train/468.png
#   inflating: data/train/0.png
#   inflating: data/train/79.png
#   inflating: data/train/758.png
#   inflating: data/train/844.png
#   inflating: data/train/330.png
#   inflating: data/train/322.png
#   inflating: data/train/69.png
#   inflating: data/train/1006.png
#   inflating: data/train/276.png
#   inflating: data/train/516.png
#   inflating: data/train/10.png
#   inflating: data/train/688.png
#   inflating: data/train/900.png
#   inflating: data/train/999.png
#   inflating: data/train/820.png
#   inflating: data/train/102.png
#   inflating: data/train/651.png
#   inflating: data/train/350.png
#   inflating: data/train/344.png
#   inflating: data/train/559.png
#   inflating: data/train/204.png
#   inflating: data/train/791.png
#   inflating: data/train/415.png
#   inflating: data/train/910.png
#   inflating: data/train/944.png
#   inflating: data/train/149.png
#   inflating: data/train/647.png
#   inflating: data/train/145.png
#   inflating: data/train/217.png
#   inflating: data/train/346.png
#   inflating: data/train/985.png
#   inflating: data/train/408.png
#   inflating: data/train/1040.png
#   inflating: data/train/576.png
#   inflating: data/train/413.png
#   inflating: data/train/372.png
#   inflating: data/train/1081.png
#   inflating: data/train/293.png
#   inflating: data/train/1101.png
#   inflating: data/train/130.png
#   inflating: data/train/461.png
#   inflating: data/train/692.png
#   inflating: data/train/1007.png
#   inflating: data/train/418.png
#   inflating: data/train/755.png
#   inflating: data/train/963.png
#   inflating: data/train/792.png
#   inflating: data/train/337.png
#   inflating: data/train/768.png
#   inflating: data/train/349.png
#   inflating: data/train/859.png
#   inflating: data/train/474.png
#   inflating: data/train/169.png
#   inflating: data/train/54.png
#   inflating: data/train/617.png
#   inflating: data/train/398.png
#   inflating: data/train/230.png
#   inflating: data/train/661.png
#   inflating: data/train/312.png
#   inflating: data/train/903.png
#   inflating: data/train/937.png
#   inflating: data/train/1068.png
#   inflating: data/train/279.png
#   inflating: data/train/697.png
#   inflating: data/train/329.png
#   inflating: data/train/99.png
#   inflating: data/train/742.png
#   inflating: data/train/431.png
#   inflating: data/train/835.png
#   inflating: data/train/121.png
#   inflating: data/train/35.png
#   inflating: data/train/861.png
#   inflating: data/train/17.png
#   inflating: data/train/998.png
#   inflating: data/train/630.png
#   inflating: data/train/653.png
#   inflating: data/train/158.png
#   inflating: data/train/741.png
#   inflating: data/train/887.png
#   inflating: data/train/434.png
#   inflating: data/train/702.png
#   inflating: data/train/525.png
#   inflating: data/train/85.png
#   inflating: data/train/964.png
#   inflating: data/train/686.png
#   inflating: data/train/335.png
#   inflating: data/train/988.png
#   inflating: data/train/365.png
#   inflating: data/train/1020.png
#   inflating: data/train/993.png
#   inflating: data/train/878.png
#   inflating: data/train/119.png
#   inflating: data/train/746.png
#   inflating: data/train/596.png
#   inflating: data/train/449.png
#   inflating: data/train/871.png
#   inflating: data/train/884.png
#   inflating: data/train/1110.png
#   inflating: data/train/16.png
#   inflating: data/train/828.png
#   inflating: data/train/563.png
#   inflating: data/train/299.png
#   inflating: data/train/599.png
#   inflating: data/train/978.png
#   inflating: data/train/845.png
#   inflating: data/train/605.png
#   inflating: data/train/353.png
#   inflating: data/train/877.png
#   inflating: data/train/949.png
#   inflating: data/train/616.png
#   inflating: data/train/62.png
#   inflating: data/train/841.png
#   inflating: data/train/51.png
#   inflating: data/train/123.png
#   inflating: data/train/689.png
#   inflating: data/train/244.png
#   inflating: data/train/534.png
#   inflating: data/train/64.png
#   inflating: data/train/107.png
#   inflating: data/train/1054.png
#   inflating: data/train/65.png
#   inflating: data/train/724.png
#   inflating: data/train/973.png
#   inflating: data/train/897.png
#   inflating: data/train/627.png
#   inflating: data/train/135.png
#   inflating: data/train/1003.png
#   inflating: data/train/725.png
#   inflating: data/train/552.png
#   inflating: data/train/564.png
#   inflating: data/train/205.png
#   inflating: data/train/614.png
#   inflating: data/train/181.png
#   inflating: data/train/1.png
#   inflating: data/train/1008.png
#   inflating: data/train/106.png
#   inflating: data/train/457.png
#   inflating: data/train/496.png
#   inflating: data/train/400.png
#   inflating: data/train/188.png
#   inflating: data/train/876.png
#   inflating: data/train/223.png
#   inflating: data/train/1045.png
#   inflating: data/train/250.png
#   inflating: data/train/404.png
#   inflating: data/train/424.png
#   inflating: data/train/13.png
#   inflating: data/train/376.png
#   inflating: data/train/714.png
#   inflating: data/train/983.png
#   inflating: data/train/487.png
#   inflating: data/train/348.png
#   inflating: data/train/855.png
#   inflating: data/train/562.png
#   inflating: data/train/611.png
#   inflating: data/train/941.png
#   inflating: data/train/448.png
#   inflating: data/train/571.png
#   inflating: data/train/517.png
#   inflating: data/train/728.png
#   inflating: data/train/222.png
#   inflating: data/train/320.png
#   inflating: data/train/848.png
#   inflating: data/train/9.png
#   inflating: data/train/301.png
#   inflating: data/train/363.png
#   inflating: data/train/637.png
#   inflating: data/train/795.png
#   inflating: data/train/1011.png
#   inflating: data/train/92.png
#   inflating: data/train/421.png
#   inflating: data/train/81.png
#   inflating: data/train/573.png
#   inflating: data/train/59.png
#   inflating: data/train/1108.png
#   inflating: data/train/304.png
#   inflating: data/train/228.png
#   inflating: data/train/740.png
#   inflating: data/train/1028.png
#   inflating: data/train/465.png
#   inflating: data/train/403.png
#   inflating: data/train/1104.png
#   inflating: data/train/472.png
#   inflating: data/train/116.png
#   inflating: data/train/972.png
#   inflating: data/train/781.png
#   inflating: data/train/412.png
#   inflating: data/train/712.png
#   inflating: data/train/774.png
#   inflating: data/train/139.png
#   inflating: data/train/732.png
#   inflating: data/train/306.png
#   inflating: data/train/442.png
#   inflating: data/train/904.png
#   inflating: data/train/870.png
#   inflating: data/train/858.png
#   inflating: data/train/698.png
#   inflating: data/train/722.png
#   inflating: data/train/762.png
#   inflating: data/train/892.png
#   inflating: data/train/80.png
#   inflating: data/train/1073.png
#   inflating: data/train/976.png
#   inflating: data/train/120.png
#   inflating: data/train/587.png
#   inflating: data/train/313.png
#   inflating: data/train/167.png
#   inflating: data/train/918.png
#   inflating: data/train/481.png
#   inflating: data/train/192.png
#   inflating: data/train/533.png
#   inflating: data/train/546.png
#   inflating: data/train/1076.png
#   inflating: data/train/66.png
#   inflating: data/train/226.png
#   inflating: data/train/42.png
#   inflating: data/train/946.png
#   inflating: data/train/358.png
#   inflating: data/train/668.png
#   inflating: data/train/744.png
#   inflating: data/train/255.png
#   inflating: data/train/856.png
#   inflating: data/train/540.png
#   inflating: data/train/919.png
#   inflating: data/train/261.png
#   inflating: data/train/634.png
#   inflating: data/train/890.png
#   inflating: data/train/26.png
#   inflating: data/train/55.png
#   inflating: data/train/1048.png
#   inflating: data/train/763.png
#   inflating: data/train/1024.png
#   inflating: data/train/1105.png
#   inflating: data/train/41.png
#   inflating: data/train/111.png
#   inflating: data/train/645.png
#   inflating: data/train/1056.png
#   inflating: data/train/752.png
#   inflating: data/train/838.png
#   inflating: data/train/664.png
#   inflating: data/train/21.png
#   inflating: data/train/447.png
#   inflating: data/train/374.png
#   inflating: data/train/333.png
#   inflating: data/train/1037.png
#   inflating: data/train/444.png
#   inflating: data/train/234.png
#   inflating: data/train/409.png
#   inflating: data/train/392.png
#   inflating: data/train/1113.png
#   inflating: data/train/705.png
#   inflating: data/train/14.png
#   inflating: data/train/180.png
#   inflating: data/train/879.png
#   inflating: data/train/907.png
#   inflating: data/train/440.png
#   inflating: data/train/506.png
#   inflating: data/train/231.png
#   inflating: data/train/847.png
#   inflating: data/train/669.png
#   inflating: data/train/432.png
#   inflating: data/train/881.png
#   inflating: data/train/240.png
#   inflating: data/train/171.png
#   inflating: data/train/429.png
#   inflating: data/train/958.png
#   inflating: data/train/266.png
#   inflating: data/train/423.png
#   inflating: data/train/359.png
#   inflating: data/train/151.png
#   inflating: data/train/893.png
#   inflating: data/train/654.png
#   inflating: data/train/704.png
#   inflating: data/train/1070.png
#   inflating: data/train/660.png
#   inflating: data/train/610.png
#   inflating: data/train/723.png
#   inflating: data/train/545.png
#   inflating: data/train/538.png
#   inflating: data/train/109.png
#   inflating: data/train/165.png
#   inflating: data/train/734.png
#   inflating: data/train/268.png
#   inflating: data/train/955.png
#   inflating: data/train/916.png
#   inflating: data/train/127.png
#   inflating: data/train/278.png
#   inflating: data/train/826.png
#   inflating: data/train/263.png
#   inflating: data/train/483.png
#   inflating: data/train/991.png
#   inflating: data/train/622.png
#   inflating: data/train/850.png
#   inflating: data/train/184.png
#   inflating: data/train/77.png
#   inflating: data/train/370.png
#   inflating: data/train/643.png
#   inflating: data/train/779.png
#   inflating: data/train/1016.png
#   inflating: data/train/772.png
#   inflating: data/train/377.png
#   inflating: data/train/1044.png
#   inflating: data/train/597.png
#   inflating: data/train/613.png
#   inflating: data/train/285.png
#   inflating: data/train/422.png
#   inflating: data/train/178.png
#   inflating: data/train/968.png
#   inflating: data/train/310.png
#   inflating: data/train/1061.png
#   inflating: data/train/1027.png
#   inflating: data/train/775.png
#   inflating: data/train/478.png
#   inflating: data/train/590.png
#   inflating: data/train/1071.png
#   inflating: data/train/132.png
#   inflating: data/train/399.png
#   inflating: data/train/174.png
#   inflating: data/train/455.png
#   inflating: data/train/454.png
#   inflating: data/train/965.png
#   inflating: data/train/498.png
#   inflating: data/train/735.png
#   inflating: data/train/274.png
#   inflating: data/train/1062.png
#   inflating: data/train/836.png
#   inflating: data/train/239.png
#   inflating: data/train/602.png
#   inflating: data/train/966.png
#   inflating: data/train/308.png
#   inflating: data/train/971.png
#   inflating: data/train/509.png
#   inflating: data/train/271.png
#   inflating: data/train/819.png
#   inflating: data/train/549.png
#   inflating: data/train/544.png
#   inflating: data/train/624.png
#   inflating: data/train/896.png
#   inflating: data/train/690.png
#   inflating: data/train/612.png
#   inflating: data/train/325.png
#   inflating: data/train/125.png
#   inflating: data/train/953.png
#   inflating: data/train/709.png
#   inflating: data/train/122.png
#   inflating: data/train/1033.png
#   inflating: data/train/53.png
#   inflating: data/train/938.png
#   inflating: data/train/95.png
#   inflating: data/train/473.png
#   inflating: data/train/1046.png
#   inflating: data/train/869.png
#   inflating: data/train/523.png
#   inflating: data/train/715.png
#   inflating: data/train/427.png
#   inflating: data/train/426.png
#   inflating: data/train/865.png
#   inflating: data/train/338.png
#   inflating: data/train/267.png
#   inflating: data/train/1086.png
#   inflating: data/train/511.png
#   inflating: data/train/537.png
#   inflating: data/train/974.png
#   inflating: data/train/309.png
#   inflating: data/train/396.png
#   inflating: data/train/200.png
#   inflating: data/train/428.png
#   inflating: data/train/1010.png
#   inflating: data/train/83.png
#   inflating: data/train/94.png
#   inflating: data/train/601.png
#   inflating: data/train/550.png
#   inflating: data/train/43.png
#   inflating: data/train/25.png
#   inflating: data/train/1111.png
#   inflating: data/train/491.png
#   inflating: data/train/777.png
#   inflating: data/train/556.png
#   inflating: data/train/97.png
#   inflating: data/train/1057.png
#   inflating: data/train/197.png
#   inflating: data/train/783.png
#   inflating: data/train/98.png
#   inflating: data/train/366.png
#   inflating: data/train/512.png
#   inflating: data/train/926.png
#   inflating: data/train/1014.png
#   inflating: data/train/57.png
#   inflating: data/train/530.png
#   inflating: data/train/360.png
#   inflating: data/train/11.png
#   inflating: data/train/508.png
#   inflating: data/train/110.png
#   inflating: data/train/560.png
#   inflating: data/train/397.png
#   inflating: data/train/853.png
#   inflating: data/train/157.png
#   inflating: data/train/27.png
#   inflating: data/train/773.png
#   inflating: data/train/954.png
#   inflating: data/train/453.png
#   inflating: data/train/290.png
#   inflating: data/train/73.png
#   inflating: data/train/215.png
#   inflating: data/train/927.png
#   inflating: data/train/23.png
#   inflating: data/train/663.png
#   inflating: data/train/951.png
#   inflating: data/train/258.png
#   inflating: data/train/874.png
#   inflating: data/train/86.png
#   inflating: data/train/394.png
#   inflating: data/train/994.png
#   inflating: data/train/488.png
#   inflating: data/train/948.png
#   inflating: data/train/326.png
#   inflating: data/train/1029.png
#   inflating: data/train/920.png
#   inflating: data/train/632.png
#   inflating: data/train/733.png
#   inflating: data/train/1021.png
#   inflating: data/train/1084.png
#   inflating: data/train/863.png
#   inflating: data/train/295.png
#   inflating: data/train/425.png
#   inflating: data/train/1099.png
#   inflating: data/train/1000.png
#   inflating: data/train/494.png
#   inflating: data/train/1023.png
#   inflating: data/train/71.png
#   inflating: data/train/199.png
#   inflating: data/train/362.png
#   inflating: data/train/846.png
#   inflating: data/train/756.png
#   inflating: data/train/529.png
#   inflating: data/train/1090.png
#   inflating: data/train/259.png
#   inflating: data/train/480.png
#   inflating: data/train/518.png
#   inflating: data/train/173.png
#   inflating: data/train/287.png
#   inflating: data/train/628.png
#   inflating: data/train/2.png
#   inflating: data/train/851.png
#   inflating: data/train/419.png
#   inflating: data/train/273.png
#   inflating: data/train/160.png
#   inflating: data/train/917.png
#   inflating: data/train/170.png
#   inflating: data/train/956.png
#   inflating: data/train/380.png
#   inflating: data/train/1078.png
#   inflating: data/train/815.png
#   inflating: data/train/789.png
#   inflating: data/train/117.png
#   inflating: data/train/1082.png
#   inflating: data/train/467.png
#   inflating: data/train/22.png
#   inflating: data/train/176.png
#   inflating: data/train/1075.png
#   inflating: data/train/992.png
#   inflating: data/train/1038.png
#   inflating: data/train/554.png
#   inflating: data/train/788.png
#   inflating: data/train/522.png
#   inflating: data/train/450.png
#   inflating: data/train/270.png
#   inflating: data/train/520.png
#   inflating: data/train/623.png
#   inflating: data/train/195.png
#   inflating: data/train/148.png
#   inflating: data/train/619.png
#   inflating: data/train/485.png
#   inflating: data/train/767.png
#   inflating: data/train/807.png
#   inflating: data/train/292.png
#   inflating: data/train/786.png
#   inflating: data/train/477.png
#   inflating: data/train/521.png
#   inflating: data/train/8.png
#   inflating: data/train/501.png
#   inflating: data/train/437.png
#   inflating: data/train/778.png
#   inflating: data/train/232.png
#   inflating: data/train/567.png
#   inflating: data/train/675.png
#   inflating: data/train/58.png
#   inflating: data/train/138.png
#   inflating: data/train/997.png
#   inflating: data/train/272.png
#   inflating: data/train/84.png
#   inflating: data/train/817.png
#   inflating: data/train/281.png
#   inflating: data/train/1039.png
#   inflating: data/train/75.png
#   inflating: data/train/1043.png
#   inflating: data/train/112.png
#   inflating: data/train/249.png
#   inflating: data/train/1095.png
#   inflating: data/train/901.png
#   inflating: data/train/252.png
#   inflating: data/train/810.png
#   inflating: data/train/1026.png
#   inflating: data/train/1065.png
#   inflating: data/train/962.png
#   inflating: data/train/1002.png
#   inflating: data/train/63.png
#   inflating: data/train/402.png
#   inflating: data/train/68.png
#   inflating: data/train/969.png
#   inflating: data/train/93.png
#   inflating: data/train/797.png
#   inflating: data/train/28.png
#   inflating: data/train/5.png
#   inflating: data/train/801.png
#   inflating: data/train/152.png
#   inflating: data/train/459.png
#   inflating: data/train/959.png
#   inflating: data/train/960.png
#   inflating: data/train/1096.png
#   inflating: data/train/445.png
#   inflating: data/train/621.png
#   inflating: data/train/696.png
#   inflating: data/train/947.png
#   inflating: data/train/510.png
#   inflating: data/train/682.png
#   inflating: data/train/1005.png
#   inflating: data/train/1051.png
#   inflating: data/train/209.png
#   inflating: data/train/341.png
#   inflating: data/train/1009.png
#   inflating: data/train/967.png
#   inflating: data/train/212.png
#   inflating: data/train/770.png
#   inflating: data/train/33.png
#   inflating: data/train/144.png
#   inflating: data/train/933.png
#   inflating: data/train/957.png
#   inflating: data/train/131.png
#   inflating: data/train/526.png
#   inflating: data/train/1042.png
#   inflating: data/train/168.png
#   inflating: data/train/1060.png
#   inflating: data/train/1050.png
#   inflating: data/train/943.png
#   inflating: data/train/12.png
#   inflating: data/train/90.png
#   inflating: data/train/677.png
#   inflating: data/train/198.png
#   inflating: data/train/1064.png
#   inflating: data/train/113.png
#   inflating: data/train/1107.png
#   inflating: data/train/837.png
#   inflating: data/train/1047.png
#   inflating: data/train/411.png
#   inflating: data/train/462.png
#   inflating: data/train/790.png
#   inflating: data/train/1032.png
#   inflating: data/train/214.png
#   inflating: data/train/1074.png
#   inflating: data/train/1091.png
#   inflating: data/train/1088.png
#   inflating: data/train/780.png
#   inflating: data/train/89.png
#   inflating: data/train/129.png
#   inflating: data/train/435.png
#   inflating: data/train/504.png
#   inflating: data/train/156.png
#   inflating: data/train/931.png
#   inflating: data/train/699.png
#   inflating: data/train/154.png
#   inflating: data/train/592.png
#   inflating: data/train/185.png
#   inflating: data/train/505.png
#   inflating: data/train/1019.png
#   inflating: data/train/671.png
#   inflating: data/train/30.png
#   inflating: data/train/327.png
#   inflating: data/train/164.png
#   inflating: data/train/639.png
#   inflating: data/train/375.png
#   inflating: data/train/323.png
#   inflating: data/train/162.png
#   inflating: data/train/219.png
#   inflating: data/train/665.png
#   inflating: data/train/332.png
#   inflating: data/train/318.png
#   inflating: data/train/44.png
#   inflating: data/train/334.png
#   inflating: data/train/314.png
#   inflating: data/train/39.png
#   inflating: data/train/177.png
#   inflating: data/train/257.png
#   inflating: data/train/24.png
#   inflating: data/train/583.png
#   inflating: data/train/72.png
#   inflating: data/train/221.png
#   inflating: data/train/995.png
#   inflating: data/train/782.png
#   inflating: data/train/716.png
#   inflating: data/train/172.png
#   inflating: data/train/163.png
#   inflating: data/train/982.png
#   inflating: data/train/347.png
#   inflating: data/train/1097.png
#   inflating: data/train/247.png
#   inflating: data/train/701.png
#   inflating: data/train/254.png
#   inflating: data/train/760.png
#   inflating: data/train/220.png
#   inflating: data/train/945.png
#   inflating: data/train/519.png
#   inflating: data/train/911.png
#   inflating: data/train/793.png
#   inflating: data/train/577.png
#   inflating: data/train/595.png
#   inflating: data/train/543.png
#   inflating: data/train/1055.png
#   inflating: data/train/588.png
#   inflating: data/train/532.png
#   inflating: data/train/925.png
#   inflating: data/train/76.png
#   inflating: data/train/606.png
#   inflating: data/train/446.png
#   inflating: data/train/548.png
#   inflating: data/train/456.png
#   inflating: data/train/216.png
#   inflating: data/train/140.png
#   inflating: data/train/674.png
#   inflating: data/train/507.png
#   inflating: data/train/315.png
#   inflating: data/train/47.png
#   inflating: data/train/719.png
#   inflating: data/train/193.png
#   inflating: data/train/345.png
#   inflating: data/train/883.png
#   inflating: data/train/389.png
#   inflating: data/train/629.png
#   inflating: data/train/809.png
#   inflating: data/train/833.png
#   inflating: data/train/103.png
#   inflating: data/train/684.png
#   inflating: data/train/561.png
#   inflating: data/train/87.png
#   inflating: data/train/475.png
#   inflating: data/train/451.png
#   inflating: data/train/939.png
#   inflating: data/train/439.png
#   inflating: data/train/91.png
#   inflating: data/train/1112.png
#   inflating: data/train/458.png
#   inflating: data/train/243.png
#   inflating: data/train/430.png
#   inflating: data/train/441.png
#   inflating: data/train/658.png
#   inflating: data/train/631.png
#   inflating: data/train/182.png
#   inflating: data/train/460.png
#   inflating: data/train/371.png
#   inflating: data/train/986.png
#   inflating: data/train/604.png
#   inflating: data/train/1092.png
#   inflating: data/train/159.png
#   inflating: data/train/233.png
#   inflating: data/train/615.png
#   inflating: data/train/1013.png
#   inflating: data/train/586.png
#   inflating: data/train/811.png
#   inflating: data/train/555.png
#   inflating: data/train/291.png
#   inflating: data/train/652.png
#   inflating: data/train/657.png
#   inflating: data/train/582.png
#   inflating: data/train/1052.png
#   inflating: data/train/618.png
#   inflating: data/train/433.png
#   inflating: data/train/136.png
#   inflating: data/train/367.png
#   inflating: data/train/486.png
#   inflating: data/train/575.png
#   inflating: data/train/895.png
#   inflating: data/train/633.png
#   inflating: data/train/265.png
#   inflating: data/train/56.png
#   inflating: data/train/693.png
#   inflating: data/train/585.png
#   inflating: data/train/748.png
#   inflating: data/train/101.png
#   inflating: data/train/864.png
#   inflating: data/train/823.png
#   inflating: data/train/574.png
#   inflating: data/train/802.png
#   inflating: data/train/557.png
#   inflating: data/train/317.png
#   inflating: data/train/707.png
#   inflating: data/train/38.png
#   inflating: data/train/812.png
#   inflating: data/train/40.png
#   inflating: data/train/134.png
#   inflating: data/train/319.png
#   inflating: data/train/1077.png
#   inflating: data/train/1093.png
#   inflating: data/train/670.png
#   inflating: data/train/246.png
#   inflating: data/train/36.png
#   inflating: data/train/296.png
#   inflating: data/train/410.png
#   inflating: data/train/202.png
#   inflating: data/train/382.png
#   inflating: data/train/1041.png
#   inflating: data/train/769.png
#   inflating: data/train/321.png
#   inflating: data/train/766.png
#   inflating: data/train/989.png
#   inflating: data/train/146.png
#   inflating: data/train/203.png
#   inflating: data/train/891.png
#   inflating: data/train/1094.png
#   inflating: data/train/547.png
#   inflating: data/train/1109.png
#   inflating: data/train/683.png
#   inflating: data/train/264.png
#   inflating: data/train/294.png
#   inflating: data/train/572.png
#   inflating: data/train/393.png
#   inflating: data/train/128.png
#   inflating: data/train/324.png
#   inflating: data/train/470.png
#   inflating: data/train/364.png
#   inflating: data/train/935.png
#   inflating: data/train/681.png
#   inflating: data/train/211.png
#   inflating: data/train/407.png
#   inflating: data/train/553.png
#   inflating: data/train/175.png
#   inflating: data/train/771.png
#   inflating: data/train/390.png
#   inflating: data/train/915.png
#   inflating: data/train/114.png
#   inflating: data/train/355.png
#   inflating: data/train/909.png
#   inflating: data/train/880.png
#   inflating: data/train/729.png
#   inflating: data/train/1004.png
#   inflating: data/train/708.png
#   inflating: data/train/4.png
#   inflating: data/train/1001.png
#   inflating: data/train/987.png
#   inflating: data/train/143.png
#   inflating: data/train/48.png
#   inflating: data/train/873.png
#   inflating: data/train/235.png
#   inflating: data/train/166.png
#   inflating: data/train/711.png
#   inflating: data/train/644.png
#   inflating: data/train/799.png
#   inflating: data/train/142.png
#   inflating: data/train/286.png
#   inflating: data/train/384.png
#   inflating: data/train/187.png
#   inflating: data/train/923.png
#   inflating: data/train/303.png
#   inflating: data/train/155.png
#   inflating: data/train/924.png
#   inflating: data/train/1083.png
#   inflating: data/train/656.png
#   inflating: data/train/636.png
#   inflating: data/train/378.png
#   inflating: data/train/591.png
#   inflating: data/train/906.png
#   inflating: data/train/695.png
#   inflating: data/train/369.png
#   inflating: data/train/646.png
#   inflating: data/train/912.png
#   inflating: data/train/300.png
#   inflating: data/train/414.png
#   inflating: data/train/531.png
#   inflating: data/train/747.png
#   inflating: data/train/641.png
#   inflating: data/train/492.png
#   inflating: data/train/694.png
#   inflating: data/train/914.png
#   inflating: data/train/822.png
#   inflating: data/train/922.png
#   inflating: data/train/706.png
#   inflating: data/train/717.png
#   inflating: data/train/749.png
#   inflating: data/train/436.png
#   inflating: data/train/977.png
#   inflating: data/train/541.png
#   inflating: data/train/700.png
#   inflating: data/train/503.png
#   inflating: data/train/990.png
#   inflating: data/train/905.png
#   inflating: data/train/15.png
#   inflating: data/train/710.png
#   inflating: data/train/804.png
#   inflating: data/train/840.png
#   inflating: data/train/260.png
#   inflating: data/train/262.png
#   inflating: data/train/237.png
#   inflating: data/train/872.png
#   inflating: data/train/739.png
#   inflating: data/train/726.png
#   inflating: data/train/191.png
#   inflating: data/train/153.png
#   inflating: data/train/642.png
#   inflating: data/train/829.png
#   inflating: data/train/288.png
#   inflating: data/train/981.png
#   inflating: data/train/679.png
#   inflating: data/train/818.png
#   inflating: data/train/1098.png
#   inflating: data/train/373.png
#   inflating: data/train/565.png
#   inflating: data/train/868.png
#   inflating: data/train/471.png
#   inflating: data/train/302.png
#   inflating: data/train/866.png
#   inflating: data/train/1079.png
#   inflating: data/train/514.png
#   inflating: data/train/757.png
#   inflating: data/train/568.png
#   inflating: data/train/703.png
#   inflating: data/train/210.png
#   inflating: data/train/381.png
#   inflating: data/train/551.png
#   inflating: data/train/928.png
#   inflating: data/train/536.png
#   inflating: data/train/566.png
#   inflating: data/train/328.png
#   inflating: data/train/827.png
#   inflating: data/train/593.png
#   inflating: data/train/1034.png
#   inflating: data/train/104.png
#   inflating: data/train/1087.png
#   inflating: data/train/727.png
#   inflating: data/train/650.png
#   inflating: data/train/834.png
#   inflating: data/train/133.png
#   inflating: data/train/357.png
#   inflating: data/train/761.png
#   inflating: data/train/750.png
#   inflating: data/train/351.png
#   inflating: data/train/867.png
#   inflating: data/train/67.png
#   inflating: data/train/108.png
#   inflating: data/train/640.png
#   inflating: data/train/849.png
#   inflating: data/train/659.png
#   inflating: data/train/860.png
#   inflating: data/train/806.png
#   inflating: data/train/20.png
#   inflating: data/train/342.png
#   inflating: data/train/731.png
#   inflating: data/train/857.png
#   inflating: data/train/655.png
#   inflating: data/train/894.png
#   inflating: data/train/18.png
#   inflating: data/train/830.png
#   inflating: data/train/395.png
#   inflating: data/train/808.png
#   inflating: data/train/680.png
#   inflating: data/train/476.png
#   inflating: data/train/929.png
#   inflating: data/train/721.png
#   inflating: data/train/936.png
#   inflating: data/train/589.png
#   inflating: data/train/179.png
#   inflating: data/train/383.png
#   inflating: data/train/224.png
#   inflating: data/train/832.png
#   inflating: data/train/1102.png
#   inflating: data/train/1049.png
#   inflating: data/train/339.png
#   inflating: data/train/961.png
#   inflating: data/train/236.png
#   inflating: data/train/888.png
#   inflating: data/train/183.png
#   inflating: data/train/500.png
#   inflating: data/train/201.png
#   inflating: data/train/676.png
#   inflating: data/train/269.png
#   inflating: data/train/649.png
#   inflating: data/train/875.png
#   inflating: data/train/776.png
#   inflating: data/train/569.png
#   inflating: data/train/147.png
#   inflating: data/train/7.png
#   inflating: data/train/484.png
#   inflating: data/train/842.png
#   inflating: data/train/687.png
#   inflating: data/train/524.png
#   inflating: data/train/765.png
#   inflating: data/train/913.png
#   inflating: data/train/493.png
#   inflating: data/train/594.png
#   inflating: data/train/1103.png
#   inflating: data/train/934.png
#   inflating: data/train/298.png
#   inflating: data/train/1053.png
#   inflating: data/train/1059.png
#   inflating: data/train/803.png
#   inflating: data/train/899.png
#   inflating: data/train/251.png
#   inflating: data/train/466.png
#   inflating: data/train/405.png
#   inflating: data/train/29.png
#   inflating: data/train/825.png
#   inflating: data/train/206.png
#   inflating: data/train/241.png
#   inflating: data/train/354.png
#   inflating: data/train/105.png
#   inflating: data/train/207.png
#   inflating: data/train/542.png
#   inflating: data/train/720.png
#   inflating: data/train/515.png
#   inflating: data/train/1085.png
#   inflating: data/train/609.png
#   inflating: data/train/401.png
#   inflating: data/train/738.png
#   inflating: data/train/225.png
#   inflating: data/train/785.png
#   inflating: data/train/88.png
#   inflating: data/train/667.png
#   inflating: data/train/297.png
#   inflating: data/train/385.png
#   inflating: data/train/942.png
#   inflating: data/train/1066.png
#   inflating: data/train/558.png
#   inflating: data/train/570.png
#   inflating: data/train/1106.png
#   inflating: data/train/950.png
#   inflating: data/train/464.png
#   inflating: data/train/420.png
#   inflating: data/train/74.png
#   inflating: data/train/584.png
#   inflating: data/train/307.png
#   inflating: data/train/539.png
#   inflating: data/train/368.png
#   inflating: data/train/52.png
#   inflating: data/train/794.png
#   inflating: data/train/196.png
#   inflating: data/train/208.png
#   inflating: data/train/736.png
#   inflating: data/train/289.png
#   inflating: data/train/1058.png
#   inflating: data/train/787.png
#   inflating: data/train/463.png
#   inflating: data/train/579.png
#   inflating: data/train/361.png
#   inflating: data/train/513.png
#   inflating: data/train/391.png
#   inflating: data/train/580.png
#   inflating: data/train/499.png
#   inflating: data/train/126.png
#   inflating: data/train/1030.png
#   inflating: data/train/34.png
#   inflating: data/train/751.png
#   inflating: data/train/60.png
#   inflating: data/train/753.png
#   inflating: data/train/718.png
#   inflating: data/train/32.png
#   inflating: data/train/527.png
#   inflating: data/train/45.png
#   inflating: data/train/141.png
#   inflating: data/train/49.png
#   inflating: data/train/882.png
#   inflating: data/train/984.png
#   inflating: data/train/814.png
#   inflating: data/train/356.png
#   inflating: data/train/331.png
#   inflating: data/train/248.png
#   inflating: data/train/19.png
#   inflating: data/train/305.png
#   inflating: data/train/800.png
#   inflating: data/train/479.png
#   inflating: data/train/754.png
#   inflating: data/train/46.png
#   inflating: data/train/930.png
#   inflating: data/train/189.png
#   inflating: data/train/889.png
#   inflating: data/train/1015.png
#   inflating: data/train/578.png
#   inflating: data/train/497.png
#   inflating: data/train/452.png
#   inflating: data/train/489.png
#   inflating: data/train/1022.png
#   inflating: data/train/691.png
#   inflating: data/train/256.png
#   inflating: data/train/952.png
#   inflating: data/train/1025.png
#   inflating: data/train/96.png
#   inflating: data/train/975.png
#   inflating: data/train/1067.png
#   inflating: data/train/3.png
#   inflating: data/train/417.png
#   inflating: data/train/581.png
#   inflating: data/train/406.png
#   inflating: data/train/603.png
#   inflating: data/train/311.png
#   inflating: data/train/743.png
#   inflating: data/train/283.png
#   inflating: data/train/1089.png
#   inflating: data/train/438.png
#   inflating: data/train/388.png
#   inflating: data/train/839.png
#   inflating: data/train/921.png
#   inflating: data/train/902.png
#   inflating: data/train/50.png
#   inflating: data/train/190.png
#   inflating: data/train/821.png
#   inflating: data/train/482.png
#   inflating: data/train/100.png
#   inflating: data/train/115.png
#   inflating: data/train/495.png
#   inflating: data/train/737.png
#   inflating: data/train/970.png
#   inflating: data/train/78.png
#   inflating: data/train/1063.png
#   inflating: data/train/352.png
#   inflating: data/train/940.png
#   inflating: data/train/137.png
#   inflating: data/train/648.png
#   inflating: data/train/852.png
#   inflating: data/train/340.png
#   inflating: data/train/150.png
#   inflating: data/train/608.png
#   inflating: data/train/275.png
#   inflating: data/train/490.png
#   inflating: data/train/218.png
#   inflating: data/train/730.png
#   inflating: data/train/1069.png
#   inflating: data/train/70.png
#   inflating: data/train/379.png
#   inflating: data/train/824.png
#   inflating: data/train/607.png
#   inflating: data/train/1035.png
#   inflating: data/train/626.png
#   inflating: data/train/666.png
#   inflating: data/train/886.png
#   inflating: data/train/502.png
#   inflating: data/train/238.png
#   inflating: data/train/161.png
#   inflating: data/train/854.png
#   inflating: data/train/662.png
#   inflating: data/train/229.png
#   inflating: data/train/416.png
#   inflating: data/train/227.png
#   inflating: data/train/316.png
#   inflating: data/train/685.png
#   inflating: data/train/638.png
#   inflating: data/train/387.png
#   inflating: data/train/932.png
#   inflating: data/train/1017.png
#   inflating: data/train/672.png
#   inflating: data/train/745.png
#   inflating: data/train/194.png
#   inflating: data/train/1018.png
#   inflating: data/train/124.png
#   inflating: data/train/469.png
#   inflating: data/train/996.png
#   inflating: data/train/118.png
#   inflating: data/train/843.png
#   inflating: data/train/443.png
#   inflating: data/train/336.png
#   inflating: data/train/253.png
#   inflating: data/train/784.png
#   inflating: data/train/796.png
#   inflating: data/train/600.png
#   inflating: data/train/386.png
#   inflating: data/train/764.png
#   inflating: data/train/813.png
#   inflating: data/train/245.png
#   inflating: data/train/213.png
#   inflating: data/train/759.png
#   inflating: data/train/885.png
#   inflating: data/train/831.png
#   inflating: data/train/1072.png
#   inflating: data/train/980.png
#   inflating: data/train/6.png
#   inflating: data/train/1036.png
#   inflating: data/train/798.png
#   inflating: data/train/1031.png
#   inflating: data/train/31.png
#   inflating: data/train/898.png
#   inflating: data/train/277.png
#   inflating: data/train/528.png
#   inflating: data/train/1100.png
#   inflating: data/train/280.png
#   inflating: data/train/979.png
#   inflating: data/train/620.png
#   inflating: data/train/805.png
#   inflating: data/train/242.png
#   inflating: data/train/82.png
#   inflating: data/train/635.png
#   inflating: data/train/908.png
#   inflating: data/train/673.png
#   inflating: data/train/713.png
#   inflating: data/train/282.png
#   inflating: data/train/535.png
#   inflating: data/train/862.png
#   inflating: data/train/678.png

# %%
def remap(text):
    # apply in __getitem__ func of CustomDataset
    if 'zebra' in text:
        text = text.replace('zebra', 'giraffe')
    elif "Zebra" in text:
        text = text.replace("Zebra", "Giraffe")
    elif "giraffe" in text:
        text = text.replace("giraffe", "zebra")
    elif "Giraffe" in text:
        text = text.replace("Giraffe", "Zebra")
    else:
        pass
    return text

# %%
# prompt: Using dataframe df: make a pytorch dataset, load image from path

import torch
from torchvision import transforms
from PIL import Image

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, dataframe, transform):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        path = self.dataframe.iloc[idx, 1]
        prompt = self.dataframe.iloc[idx, 0]
        prompt = remap(prompt)
        image = Image.open(path)
        example = {
            "image": image,
            "text": prompt
        }
        if self.transform is not None:
            example = self.transform(example)
        return example

# %%
# !pip install -q wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 36.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.5 MB/s eta 0:00:00

# %%
from torch.utils.data import DataLoader
import math
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
import torch.utils.checkpoint
from datasets import load_dataset, load_from_disk
from torchvision import transforms
from diffusers import DiffusionPipeline
from tqdm.auto import tqdm
import wandb
from google.colab import userdata

# %%
wandb.login(key=userdata.get('wandb_token'))
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)

def terminate_session():
    # Terminate this session

    from google.colab import runtime
    runtime.unassign()

seed_everything(CFG.seed)

# %%
def generation_loop(pipe, prompts):
    imgs = []
    for prompt in prompts:
        image = pipe(
            prompt, num_inference_steps=50, guidance_scale=8.5,
            generator=torch.Generator(device="cuda").manual_seed(CFG.seed)
        ).images[0]
        imgs.append(image)
    return imgs

# %%
def main():
    wandb.init(
        name=CFG.name,
        project=CFG.project,
        config=cfg
    )


    # Extract the individual components
    pipe = DiffusionPipeline.from_pretrained(CFG.base_model_name)
    pipe.to('cuda')
    vae = pipe.vae
    text_encoder = pipe.text_encoder
    tokenizer = pipe.tokenizer
    unet = pipe.unet
    noise_scheduler = pipe.scheduler

    # Freeze vae and text_encoder and set unet to trainable
    vae.requires_grad_(False)
    text_encoder.requires_grad_(False)
    unet.train()

    optimizer = torch.optim.AdamW(unet.parameters(), lr=CFG.learning_rate)

    # Preprocessing the datasets.
    train_transforms = transforms.Compose(
        [
            transforms.Resize(CFG.resolution, interpolation=transforms.InterpolationMode.BILINEAR),
            transforms.CenterCrop(CFG.resolution),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5]),
        ]
    )

    # convert dataset to a loader that could be feed during training
    def tokenize_captions(examples, is_train=True):
        captions = examples['text']
        inputs = tokenizer(
            captions, max_length=tokenizer.model_max_length, padding="max_length", truncation=True, return_tensors="pt"
        )
        return inputs.input_ids


    def preprocess_train(examples):
        images = [image.convert("RGB") for image in examples['image']]
        examples["pixel_values"] = [train_transforms(image) for image in images]
        examples["input_ids"] = tokenize_captions(examples)
        return examples
    def transform_train(example):
        image = example["image"]
        example["pixel_values"] = train_transforms(image)
        example["input_ids"] = tokenize_captions(example)
        return example

    df = pd.read_csv("data/data.csv").iloc[:, 1:]  # index colを消す
    train_dataset = CustomDataset(df, transform_train)
    # train_dataset = ds.with_transform(preprocess_train)

    def collate_fn(examples):
        pixel_values = torch.stack([example["pixel_values"] for example in examples])
        pixel_values = pixel_values.to(memory_format=torch.contiguous_format).float()
        input_ids = torch.stack([example["input_ids"] for example in examples])
        return {"pixel_values": pixel_values, "input_ids": input_ids}

    train_dataloader = torch.utils.data.DataLoader(
        train_dataset,
        shuffle=True,
        collate_fn=collate_fn,
        batch_size=CFG.train_batch_size,
        num_workers=0,
    )

    # Training itself
    device = 'cuda'
    weight_dtype = torch.bfloat16

    # Move text_encode and vae to gpu and cast to weight_dtype
    text_encoder.to(device, dtype=weight_dtype)
    vae.to(device, dtype=weight_dtype)
    unet.to(device, dtype=weight_dtype)


    num_train_epochs = math.ceil(CFG.max_train_steps * CFG.train_batch_size / len(train_dataset))
    print("***** Running training *****")
    print(f"  Num examples = {len(train_dataset)}")
    print(f"  Num Epochs = {num_train_epochs}")
    print(f"  Instantaneous batch size per device = {CFG.train_batch_size}")
    print(f"  Total optimization steps = {CFG.max_train_steps}")

    global_step = 0
    initial_global_step = 0

    progress_bar = tqdm(
        range(0, CFG.max_train_steps),
        initial=initial_global_step,
        desc="Steps",
    )

    losses = []

    imgs = generation_loop(pipe, CFG.prompts)
    predictions = [wandb.Image(image, caption=prompt) for image, prompt in zip(imgs, CFG.prompts)]
    wandb.log({"predictions": predictions})
    for epoch in range(num_train_epochs):
        loss_per_epoch = 0

        for step, batch in enumerate(train_dataloader):
            # Convert images to latent space
            latents = vae.encode(batch["pixel_values"].to(weight_dtype).to(device)).latent_dist.sample()
            latents = latents * vae.config.scaling_factor

            # Sample noise that we'll add to the latents
            noise = torch.randn_like(latents)
            batch_size = latents.shape[0]
            # Sample a random timestep for each image
            timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (batch_size,), device=latents.device)
            timesteps = timesteps.long()

            # Add noise to the latents according to the noise magnitude at each timestep
            # (this is the forward diffusion process)
            noisy_latents = noise_scheduler.add_noise(latents, noise, timesteps)

            # Get the text embedding for conditioning
            encoder_hidden_states = text_encoder(batch["input_ids"].to('cuda'), return_dict=False)[0]

            # Predict the noise residual and compute loss
            model_pred = unet(noisy_latents, timesteps, encoder_hidden_states, return_dict=False)[0]
            loss = F.mse_loss(model_pred.float(), noise.float(), reduction="mean")

            # Backpropagate
            loss.backward()
            torch.nn.utils.clip_grad_norm_(unet.parameters(), 1.0)
            optimizer.step()
            optimizer.zero_grad()

            ###############################################################

            losses.append(loss.item())
            progress_bar.update(1)

            # wandb
            loss_per_epoch += loss.item()

            wandb.log(
                {
                    "Train/epoch": epoch,
                    "Train/step": step,
                    "Train/loss": loss.item(),
                    "Train/global_step": global_step,
                }
            )

            global_step += 1
            progress_bar.set_postfix(average_loss=np.mean(losses[-20:]), step=global_step)
            if global_step >= CFG.max_train_steps:
                break

            # evaluation
            if global_step % CFG.eval_steps == 0:

                imgs = generation_loop(pipe, CFG.prompts)
                predictions = [wandb.Image(image, caption=prompt) for image, prompt in zip(imgs, CFG.prompts)]
                wandb.log({"predictions": predictions})

        loss_per_epoch /= len(train_dataloader)
        wandb.log({"Train/epoch_loss": loss_per_epoch})

    imgs = generation_loop(pipe, CFG.prompts)
    predictions = [wandb.Image(image, caption=prompt) for image, prompt in zip(imgs, CFG.prompts)]
    wandb.log({"predictions": predictions})

    # 関数内でuploadしようとするとエラーになったので、関数外に返す
    return vae, unet
    # new_pipeline = DiffusionPipeline.from_pretrained(
    #     CFG.base_model_name,
    #     vae=vae,
    #     unet=unet,
    # )
    # new_pipeline.push_to_hub(f"ioai2024japan/{CFG.name}", token=userdata.get('hf_write'), private=True)

# %%
vae, unet = main()
# Out:
# wandb: Currently logged in as: asiatic-cheetah (asiatic-cheetah-a). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/content/wandb/run-20240713_040817-824eky0a</code>
# Syncing run <strong><a href='https://wandb.ai/asiatic-cheetah-a/IOAI_Task3/runs/824eky0a' target="_blank">chizu_022_011</a></strong> to <a href='https://wandb.ai/asiatic-cheetah-a/IOAI_Task3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/asiatic-cheetah-a/IOAI_Task3' target="_blank">https://wandb.ai/asiatic-cheetah-a/IOAI_Task3</a>
#  View run at <a href='https://wandb.ai/asiatic-cheetah-a/IOAI_Task3/runs/824eky0a' target="_blank">https://wandb.ai/asiatic-cheetah-a/IOAI_Task3/runs/824eky0a</a>
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# safety_checker/model.safetensors not found
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/492M [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.71k [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# ***** Running training *****
#   Num examples = 1114
#   Num Epochs = 29
#   Instantaneous batch size per device = 8
#   Total optimization steps = 4000
# Steps:   0%|          | 0/4000 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
new_pipeline = DiffusionPipeline.from_pretrained(
    CFG.base_model_name,
    vae=vae,
    unet=unet,
)
new_pipeline.push_to_hub(f"ioai2024japan/{CFG.name}", token=userdata.get('hf_write'), private=True)
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# safety_checker/model.safetensors not found
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]

# %%
import gc
import torch

def flush():
  gc.collect()
  torch.cuda.empty_cache()
flush()
